# %%
import pandas as pd
df = pd.read_excel('cleaned_superstore_dataset.xlsx')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.to_excel('cleaned_superstore_dataset.xlsx', index = False, sheet_name='CleanedData')
